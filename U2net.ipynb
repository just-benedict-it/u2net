# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive
# Out:
# Mounted at /content/drive
# /content/drive

# %%
# clone은 처음 실행할 때 한번만 하면 됨.
# %cd /content/drive/MyDrive/
# !git clone https://github.com/NathanUA/U-2-Net.git

# %%
# u2net.pth을 U-2-Net/saved_models/u2net에 넣어줌.
# 경로가 존재하지 않는 경우 직접 만들어야함.

# %%
# 백그라운드를 제거하고 싶은 이미지가 있는 폴더경로.
input_path = "/content/drive/MyDrive/plenoxels/Custom/amongus"

# %%
#이미지들이 있는 폴더경로를 주면 이미지의 이름을 바꾸줌 ex) 0.png
# %cd /content/drive/MyDrive/plenoxels/Custom
# !python rename.py --image_path {input_path}
# Out:
# /content/drive/MyDrive/plenoxels/Custom

# %%
#이미지 경로를 주면 이미지 경로_mask 폴더를 만든 후, 그 폴더에 mask된 이미지를 저장.
# %cd /content/drive/MyDrive/U-2-Net
# !python u2net_test.py --image_path {input_path}
# Out:
# /content/drive/MyDrive/U-2-Net
# ['/content/drive/MyDrive/plenoxels/Custom/amongus/0.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/1.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/2.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/3.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/4.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/5.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/6.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/7.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/8.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/9.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/10.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/11.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/12.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/13.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/14.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/15.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/16.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/17.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/18.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/19.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/20.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/21.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/22.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/23.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/24.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/25.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/26.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/27.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/28.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/29.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/30.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/31.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/32.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/33.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/34.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/35.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/36.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/37.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/38.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/39.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/40.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/41.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/42.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/43.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/44.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/45.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/46.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/47.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/48.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/49.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/50.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/51.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/52.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/53.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/54.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/55.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/56.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/57.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/58.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/59.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/60.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/61.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/62.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/63.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/64.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/65.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/66.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/67.jpg', '/content/drive/MyDrive/plenoxels/Custom/amongus/68.jpg', '/conte ...
# ...load U2NET---173.6 MB
# mask_dir: /content/drive/MyDrive/plenoxels/Custom/amongus_mask
# inferencing: 0.jpg
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3509: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3635: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1806: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# inferencing: 1.jpg
# inferencing: 2.jpg
# inferencing: 3.jpg
# inferencing: 4.jpg
# inferencing: 5.jpg
# inferencing: 6.jpg
# inferencing: 7.jpg
# inferencing: 8.jpg
# inferencing: 9.jpg
# inferencing: 10.jpg
# inferencing: 11.jpg
# inferencing: 12.jpg
# inferencing: 13.jpg
# inferencing: 14.jpg
# inferencing: 15.jpg
# inferencing: 16.jpg
# inferencing: 17.jpg
# inferencing: 18.jpg
# inferencing: 19.jpg
# inferencing: 20.jpg
# inferencing: 21.jpg
# inferencing: 22.jpg
# inferencing: 23.jpg
# inferencing: 24.jpg
# inferencing: 25.jpg
# inferencing: 26.jpg
# inferencing: 27.jpg
# inferencing: 28.jpg
# inferencing: 29.jpg
# inferencing: 30.jpg
# inferencing: 31.jpg
# inferencing: 32.jpg
# inferencing: 33.jpg
# inferencing: 34.jpg
# inferencing: 35.jpg
# inferencing: 36.jpg
# inferencing: 37.jpg
# inferencing: 38.jpg
# inferencing: 39.jpg
# inferencing: 40.jpg
# inferencing: 41.jpg
# inferencing: 42.jpg
# inferencing: 43.jpg
# inferencing: 44.jpg
# inferencing: 45.jpg
# inferencing: 46.jpg
# inferencing: 47.jpg
# inferencing: 48.jpg
# inferencing: 49.jpg
# inferencing: 50.jpg
# inferencing: 51.jpg
# inferencing: 52.jpg
# inferencing: 53.jpg

# %%
# 이미지 경로를 주면 이미지 경로_rm_bg 폴더를 만든 후, 그 폴더에 백그라운드 제거된 이미지를 저장.
# %cd /content/drive/MyDrive/plenoxels/Custom
# !python mask.py --image_path {input_path}
# Out:
# /content/drive/MyDrive/plenoxels/Custom
# 3
# output_dir: /content/drive/MyDrive/plenoxels/Custom/amongus_rm_bg
# Masking image 0 completed.
#
# Masking image 1 completed.
#
# Masking image 2 completed.
